# %%
#L[0] = (TextView)findViewById(R.id._1);
for i in range(1,100) :
    print('L[' + str(i-1)+'] = (TextView)findViewById(R.id._'+str(i)+');')
# Out:
# L[0] = (TextView)findViewById(R.id._1);
# L[1] = (TextView)findViewById(R.id._2);
# L[2] = (TextView)findViewById(R.id._3);
# L[3] = (TextView)findViewById(R.id._4);
# L[4] = (TextView)findViewById(R.id._5);
# L[5] = (TextView)findViewById(R.id._6);
# L[6] = (TextView)findViewById(R.id._7);
# L[7] = (TextView)findViewById(R.id._8);
# L[8] = (TextView)findViewById(R.id._9);
# L[9] = (TextView)findViewById(R.id._10);
# L[10] = (TextView)findViewById(R.id._11);
# L[11] = (TextView)findViewById(R.id._12);
# L[12] = (TextView)findViewById(R.id._13);
# L[13] = (TextView)findViewById(R.id._14);
# L[14] = (TextView)findViewById(R.id._15);
# L[15] = (TextView)findViewById(R.id._16);
# L[16] = (TextView)findViewById(R.id._17);
# L[17] = (TextView)findViewById(R.id._18);
# L[18] = (TextView)findViewById(R.id._19);
# L[19] = (TextView)findViewById(R.id._20);
# L[20] = (TextView)findViewById(R.id._21);
# L[21] = (TextView)findViewById(R.id._22);
# L[22] = (TextView)findViewById(R.id._23);
# ...
